# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
n=nom.geocode("3666 21st St, San Francisco")
print(n)
# Out:
# 3666 21st St, San Francisco, California, 94114

# %%
n.latitude
# Out:
# 37.756648011392286

# %%
import pandas
from google.colab import files
df = files.upload()
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#      <input type="file" id="files-ba190ae2-8f7a-48dc-af96-192cf0bc56d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba190ae2-8f7a-48dc-af96-192cf0bc56d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supermarkets.csv to supermarkets (1).csv
#    ID          Address           City  ... Country         Name Employees
# 0   1     3666 21st St  San Francisco  ...     USA      Madeira         8
# 1   2   735 Dolores St  San Francisco  ...     USA  Bready Shop        15
# 2   3      332 Hill St  San Francisco  ...     USA  Super River        25
# 3   4     3995 23rd St  San Francisco  ...     USA   Ben's Shop        10
# 4   5  1056 Sanchez St  San Francisco  ...     USA      Sanchez        12
# 5   6  551 Alvarado St  San Francisco  ...     USA   Richvalley        20
#
# [6 rows x 7 columns]

# %%
df["Address"] = df["Address"]+", "+df["City"]+", "+df["State"]+","+df["Country"]
df
# Out:
#    ID                                           Address  ...         Name Employees
# 0   1         3666 21st St, San Francisco, CA 94114,USA  ...      Madeira         8
# 1   2       735 Dolores St, San Francisco, CA 94119,USA  ...  Bready Shop        15
# 2   3  332 Hill St, San Francisco, California 94114,USA  ...  Super River        25
# 3   4         3995 23rd St, San Francisco, CA 94114,USA  ...   Ben's Shop        10
# 4   5    1056 Sanchez St, San Francisco, California,USA  ...      Sanchez        12
# 5   6      551 Alvarado St, San Francisco, CA 94114,USA  ...   Richvalley        20
#
# [6 rows x 7 columns]

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)

df
# Out:
#    ID  ...   Latitude
# 0   1  ...  37.756648
# 1   2  ...  37.757819
# 2   3  ...  37.755875
# 3   4  ...  37.752922
# 4   5  ...  37.752131
# 5   6  ...  37.753511
#
# [6 rows x 9 columns]

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756648011392286, -122.42937496976432, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.756648011392286

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x:x.latitude)
df
# Out:
#    ID  ...   Latitude
# 0   1  ...  37.756648
# 1   2  ...  37.757819
# 2   3  ...  37.755875
# 3   4  ...  37.752922
# 4   5  ...  37.752131
# 5   6  ...  37.753511
#
# [6 rows x 9 columns]

# %%
df["Longitude"]=df["Coordinates"].apply(lambda x:x.longitude)
df
# Out:
#    ID                                           Address  ...   Latitude   Longitude
# 0   1         3666 21st St, San Francisco, CA 94114,USA  ...  37.756648 -122.429375
# 1   2       735 Dolores St, San Francisco, CA 94119,USA  ...  37.757819 -122.425337
# 2   3  332 Hill St, San Francisco, California 94114,USA  ...  37.755875 -122.428816
# 3   4         3995 23rd St, San Francisco, CA 94114,USA  ...  37.752922 -122.431697
# 4   5    1056 Sanchez St, San Francisco, California,USA  ...  37.752131 -122.430028
# 5   6      551 Alvarado St, San Francisco, CA 94114,USA  ...  37.753511 -122.433229
#
# [6 rows x 10 columns]
