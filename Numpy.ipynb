# %%
import numpy
n=numpy.arange(27)

# %%
n.reshape(3,3,3)

# %%
import cv2

# %%
img=cv2.imread("smallgray.png",1)
# 1 for blue,green,red on OpenCV
img

# %%
img=cv2.imread("smallgray.png",0) 
# 0 for grayscale
img
# Out:
# array([[187, 158, 104, 121, 143],
#        [198, 125, 255, 255, 147],
#        [209, 134, 255,  97, 182]], dtype=uint8)

# %%
cv2.imwrite("newsmallgray.png", img)
# Out:
# True

# %%
img[0:2,2:4 ]
# Out:
# array([[104, 121],
#        [255, 255]], dtype=uint8)

# %%
img[0:2]
# Out:
# array([[187, 158, 104, 121, 143],
#        [198, 125, 255, 255, 147]], dtype=uint8)

# %%
for i in img:
  print(i)
# Out:
# [187 158 104 121 143]
# [198 125 255 255 147]
# [209 134 255  97 182]

# %%
for i in img.flat:
  print(i)

# %%
img=cv2.imread("smallgray.png",0) 
# 0 for grayscale
img
# Out:
# array([[187, 158, 104, 121, 143],
#        [198, 125, 255, 255, 147],
#        [209, 134, 255,  97, 182]], dtype=uint8)

# %%
 img1=numpy.hstack((img,img))

# %%
print(img1)
# Out:
# [[187 158 104 121 143 187 158 104 121 143]
#  [198 125 255 255 147 198 125 255 255 147]
#  [209 134 255  97 182 209 134 255  97 182]]

# %%
img1=numpy.vstack((img,img))
print(img1)
# Out:
# [[187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]
#  [187 158 104 121 143]
#  [198 125 255 255 147]
#  [209 134 255  97 182]]

# %%
lst=numpy.vsplit(img1,3)
lst
